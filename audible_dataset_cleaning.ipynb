# %%
import pandas as pd

# %%
dt = pd.read_csv('audible_uncleaned.csv')
dt
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
#we verified if it exist isnull values in dataset
dt.isnull().sum()
# Out:
# name           0
# author         0
# narrator       0
# time           0
# releasedate    0
# language       0
# stars          0
# price          0
# dtype: int64

# %%
#Now we will arrange columns like author, narrator, time and stars. We start with author column. 
#We will remove Writtenby text
dt['author'] = dt['author'].str.replace('Writtenby:','')
dt['author']
# Out:
# 0        GeronimoStilton
# 1            RickRiordan
# 2             JeffKinney
# 3            RickRiordan
# 4            RickRiordan
#               ...
# 87484       ChrisStewart
# 87485      StephenO'Shea
# 87486          MarkTwain
# 87487     LaurenceSterne
# 87488      MarkKurlansky
# Name: author, Length: 87489, dtype: object

# %%
#We remove Narreted by in the culomn narrator
dt['narrator'] = dt['narrator'].str.replace('Narratedby:','')
dt['narrator']
# Out:
# 0            BillLobely
# 1         RobbieDaymond
# 2            DanRussell
# 3        SoneelaNankani
# 4        JesseBernstein
#               ...
# 87484      ChrisStewart
# 87485        RobertFass
# 87486         FloGibson
# 87487       AntonLesser
# 87488       FleetCooper
# Name: narrator, Length: 87489, dtype: object

# %%
#We treat well time column to be best written
# extract hours and minutes by using regular expression which consider space between number and texte
hours = dt['time'].str.extract(r'(\d+)\s*hrs').astype(float)  # Use float for manage Nan values
minutes = dt['time'].str.extract(r'(\d+)\s*mins').astype(float)

# Convert hours in minutes
hours_in_min = hours * 60

# Calculate sum of minutes
total_min = hours_in_min.fillna(0) + minutes.fillna(0)  # Use fillna to replace NaN by 0 before sum

# Save sum in time column
dt['time'] = total_min

# print update dataframe
dt
# Out:
#                                              name           author  \
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator    time releasedate language  \
# 0          BillLobely   140.0    04-08-08  English
# 1       RobbieDaymond   788.0    01-05-18  English
# ...

# %%
#Now we divide stars column in two one for stars and the other one for ratings
dt['ratings'] = dt['stars']
dt
# Out:
#                                              name           author  \
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator    time releasedate language  \
# 0          BillLobely   140.0    04-08-08  English
# 1       RobbieDaymond   788.0    01-05-18  English
# ...

# %%
#we keep just stars informations in stars column
dt['stars'] = dt['stars'].str.extract(r'(\d+\.\d+|\d+)')
dt['stars']
# Out:
# 0          5
# 1        4.5
# 2        4.5
# 3        4.5
# 4        4.5
#         ...
# 87484    NaN
# 87485    NaN
# 87486    NaN
# 87487    NaN
# 87488    NaN
# Name: stars, Length: 87489, dtype: object

# %%
#for Nan value we will change them by zero
dt['stars'].fillna(value=0.0, inplace=True)
dt['stars']
# Out:
# 0          5
# 1        4.5
# 2        4.5
# 3        4.5
# 4        4.5
#         ...
# 87484    0.0
# 87485    0.0
# 87486    0.0
# 87487    0.0
# 87488    0.0
# Name: stars, Length: 87489, dtype: object

# %%
#Now we select ratings in ratings's column
#we keep just stars informations in stars column
dt['ratings'] = dt['ratings'].str.extract(r'(\d+) ratings')
dt['ratings']
# Out:
# 0         34
# 1         41
# 2         38
# 3         12
# 4        181
#         ...
# 87484    NaN
# 87485    NaN
# 87486    NaN
# 87487    NaN
# 87488    NaN
# Name: ratings, Length: 87489, dtype: object

# %%
#We will just replace Nan values by O
dt['ratings'].fillna(value=0.0, inplace=True)
dt['ratings']
# Out:
# 0         34
# 1         41
# 2         38
# 3         12
# 4        181
#         ...
# 87484    0.0
# 87485    0.0
# 87486    0.0
# 87487    0.0
# 87488    0.0
# Name: ratings, Length: 87489, dtype: object

# %%
dt
# Out:
#                                              name           author  \
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator    time releasedate language stars   price ratings
# 0          BillLobely   140.0    04-08-08  English     5  468.00      34
# ...
